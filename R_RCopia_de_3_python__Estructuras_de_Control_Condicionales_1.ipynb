# %% [markdown]
# <a href="https://colab.research.google.com/github/QUISPELINO/PHYTON_CLASES_UTEC/blob/main/R_RCopia_de_3_python__Estructuras_de_Control_Condicionales_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#
#   Universidad : UTEC \\
#   Curso       : Programa de especialización en python \\
#   Profesor    : Cristian López Del Alamo y Bucles

# %% [markdown]
# # Palabras reservadas en python:
# -------------------
#
# Las palabras reservadas son aquellas palabras que tienen un significado especial y predefinido en el lenguaje, y que no pueden ser utilizadas como nombres de variables, funciones u otros identificadores del programa. Estas palabras reservadas son parte de la sintaxis del lenguaje y tienen un uso específico en el mismo.
#
# -------------------
#
#
# | Palabra reservada | Descripción |
# | --- | --- |
# | `False` | Valor booleano falso |
# | `True` | Valor booleano verdadero |
# | `None` | Valor especial que indica ausencia de valor |
# | `and` | Operador lógico "y" |
# | `as` | Utilizado para crear un alias de un módulo o nombre de clase |
# | `assert` | Se utiliza para asegurarse de que una expresión es verdadera |
# | `break` | Se utiliza para salir de un bucle |
# | `class` | Se utiliza para definir una clase |
# | `continue` | Se utiliza para continuar con la siguiente iteración de un bucle |
# | `def` | Se utiliza para definir una función |
# | `del` | Se utiliza para eliminar una variable o elemento de una lista |
# | `elif` | Se utiliza en una estructura if-else para agregar una condición adicional |
# | `else` | Se utiliza en una estructura if-else para definir el bloque de código que se ejecuta si la condición es falsa |
# | `except` | Se utiliza en una estructura try-except para manejar excepciones |
# | `finally` | Se utiliza en una estructura try-finally para definir un bloque de código que se ejecuta siempre, independientemente de si se produce una excepción o no |
# | `for` | Se utiliza para definir un bucle for |
# | `from` | Se utiliza para importar un módulo específico o partes de un módulo |
# | `global` | Se utiliza para declarar una variable global |
# | `if` | Se utiliza para definir una estructura if-else |
# | `import` | Se utiliza para importar módulos |
# | `in` | Se utiliza para comprobar si un elemento está en una secuencia |
# | `is` | Se utiliza para comparar si dos objetos son el mismo objeto |
# | `lambda` | Se utiliza para definir funciones anónimas |
# | `nonlocal` | Se utiliza para declarar una variable no local |
# | `not` | Operador lógico "no" |
# | `or` | Operador lógico "o" |
# | `pass` | Se utiliza como marcador de posición para código que aún no se ha implementado |
# | `raise` | Se utiliza para generar una excepción |
# | `return` | Se utiliza para devolver un valor de una función |
# | `try` | Se utiliza para definir una estructura try-except |
# | `while` | Se utiliza para definir un bucle while |
# | `with` | Se utiliza para definir un contexto de ejecución para un objeto |
# | `yield` | Se utiliza en funciones generadoras para devolver un valor y pausar la ejecución temporalmente |

# %% [markdown]
# #2.1 Estructuras de control IF - ELSE
# -------------------------
# Las estructuras de control **if-else** permiten controlar el flujo de información dentro de los algoritmos o programas. Si la condición dentro de la estructura if es verdadera, entonces se ejecuta un bloque de instrucciones; en caso contrario, se ejecuta otro bloque distinto de instrucciones dentro de la estructura **else**.
#
# --------------------------
#
# ## 2.1.1 Pseudocódigo de instrucción
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 2.1.2 Código en python
# --------------------------
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 2.1.3 Ejemplos.

# %%
# Ejemplo 1: Estructura if básica
#def Mayor_edad(edad):
 # if edad >= 18:
    #print("Eres mayor de edad")
    #print("Programación en python")
    #return 1
    #print("Perúuuuuu")
    


#salida = Mayor_edad(18)
#print(salida)

def Numero_entero(numero):
  if numero % 2 == 0:
   print('NUMERO PAR')
  else:
    print('NUMERO IMPAR')

Numero_entero(101)

def
# Out:
# NUMERO IMPAR

# %%
# Ejemplo 2: Estructura if-else
def Mayor_edad_1(edad):
  if edad >= 18:
      print("Eres mayor de edad")
      return 1    
      print("Perú")
  else:
      print("Eres menor de edad")


solucion = Mayor_edad_1(19)
print(solucion)
# Out:
# Eres mayor de edad
# 1

# %%
# Ejemplo 3: Estructura if anidada
def mayor_edad_2(edad, nacionalidad):
  if edad >= 18:
      if nacionalidad == "peruana":
          print("Eres mayor de edad y eres peruana")
      else:
          print("Eres mayor de edad pero no eres peruana")
  else:
      print("Eres menor de edad")
      print("Peruuu")    
mayor_edad_2(20,"Argentina")
# Out:
# Eres mayor de edad pero no eres peruana

# %%
# Ejemplo 4: Estructura if-elif-else
def Notas(nota):
  if nota >= 9:
      print("Sobresaliente")
  elif nota >= 7:
      print("Notable")
  elif nota >= 5:
      print("Aprobado")
  else:
      print("Jalado")
Notas(12)

def notas(nota):
  if nota <= 10 and nota >=0:
    print('burro')
  if nota >=10 and nota <=14:
    print('regular')  
  elif nota >= 15 and nota <=20:
    print ('diferente')
  else:
    print ('marciano')
notas(100)
# Out:
# Sobresaliente
# marciano

# %%
#Ejercicios: Definimos una función círculo el cual permite graficar un círcul de radio R, con centro en c_x, c_y.

import matplotlib.pyplot as plt
import numpy as np



def plot_circulo(radio, c_x, c_y):
  #theta = np.linspace(0, 2*np.pi, 100)
  #x = c_x + radio*np.cos(theta)
  #y = c_y + radio*np.sin(theta)
  #plt.plot(x, y)
  

#plot_circulo(20, 10,10)
#plot_circulo(5, 60,10)
#plot_circulo(7, 10,10)


plt.show()

import matplotlib.pyplot as plt
import numpy as np

plot_circulo(20, 10,10)
# Out:
#   File "<ipython-input-29-cf8271e6d90f>", line 19
#     import matplotlib.pyplot as plt
#     ^
# IndentationError: expected an indented block after function definition on line 8

# %% [markdown]
# 1. Crear una función para indicar si un círculo está dentro de otro.
# 2. Crear una función para indicar si dos círculos se tocan.
# 3. Crear una función para indicar si dos círculos están separados.
# 4. Crear una función que retorn 1, si dos círculos se tocan, -1 si no se tocan y 0 si uno está dentro de otro.
#
# Nota: en todos los casos, la función debe recibir el radio1, radio2, cx1, cy1, cx2 y cy2. Luego deberá llamar a la función plot_circulo y graficar los círculos de modo que se pueda verificar si su respuesta es correcta.

# %%
def circulo_in(radio1, radio2, cx1,cy1, cx2, cy2):
   d = np.sqrt((cx1 - cx2)**2 + (cy1 - cy2)**2)
   if radio1 > radio2:
    if radio1 > d:
      return 1
    else:
      return 0
    if radio2 > radio1:
      if radio2 > d:
        return 1
      else:
        return 0
    else:
      return 0


print(circulo_in(10,5,2,2,6,6))
plot_circulo(10, 2,2)
plot_circulo(5, 6,6)
# Out:
# True

# %% [markdown]
# #2.1 Estructuras de control FOR:
#
# ------------------
#
# La estructura de control **for** se utiliza para iterar sobre una secuencia de elementos (por ejemplo, una lista, una tupla, un diccionario, etc.). La sintaxis básica es la siguiente:
#
# --------------------
#
#     # for variable in secuencia:
#      # Cuerpo del bucle

# %% [markdown]
# # Ejercicios para hacer en clase.
#
# 1.    Imprimir los números del 1 al 10.
# 2.    Imprimir los números pares del 1 al 20.
# 3.    Imprimir los números impares del 1 al 20.
# 4.    Pedir al usuario que ingrese un número entero y luego imprimir los números del 1 al número ingresado.
# 5.     Pedir al usuario que ingrese una palabra y luego imprimir cada letra en una línea separada.
# 6.    Pedir al usuario que ingrese un número entero y luego imprimir los números pares del 1 al número ingresado.
# 7.     Pedir al usuario que ingrese una cadena y luego imprimir cada palabra en una línea separada.
# 8.    Imprimir la tabla de multiplicar del 7.
# 9.    Pedir al usuario que ingrese un número entero y luego imprimir la tabla de multiplicar de ese número.
# 10.   Pedir al usuario que ingrese un número entero y luego imprimir la suma de todos los números del 1 al número ingresado.

# %%
def sumatoria(n):
  s = 0
  for i in range(0,n):
    s = s + i
  print(s)

sumatoria(5)
# Out:
# 10

# %%
# range nos permite tener un conjunto de datos que inicia en init, termina en end, e incrementa de step
# range(init, end, step)
def saludar(n):
  for i in range(1,n,2):
    print("hola")

saludar(10)
# Out:
# hola
# hola
# hola
# hola
# hola

# %%
def misterio(n):
  s = 1
  for i in range(1,n+1):
    s=s*i 
  return s
# Out:
# 24

# %%
def misterio(n):
  s = 1
  for i in range(1,n+1):
    s=s*n
  return s

print(misterio(4))
# Out:
# 256

# %%
def misterio(a,b):
  s = 1
  p = abs(b)
  for i in range(1,p+1):
    s=s*a
  if (b<0):
    return 1/s
  return s

print(misterio(2,0))
# Out:
# 1

# %%
  print(misterio(10))

# %%
# Out:
# ********  *************

# %% [markdown]
# # Ejercicios para casa:
#     1. Imprimir un patrón de asteriscos en forma de triángulo.
#     2. Imprimir una tabla de multiplicar del 1 al 10 para todos los números del 1 al 10.
#     3. Imprimir un patrón de asteriscos en forma de diamante.
#     4. Imprimir una matriz de 5x5 con números aleatorios del 1 al 10.
#     5. Pedir al usuario que ingrese un número entero y luego imprimir un patrón de asteriscos en forma de triángulo invertido de altura igual al número ingresado.
#     6. Imprimir una matriz triangular inferior de 5x5 con números aleatorios del 1 al 10.
#     7. Pedir al usuario que ingrese un número entero y luego imprimir un patrón de asteriscos en forma de pirámide de altura igual al número ingresado.
#     8. Imprimir una matriz de 4x4 con números que representen su posición en la matriz.
#     9. Pedir al usuario que ingrese dos números enteros y luego imprimir una tabla de multiplicar desde el primer número hasta el segundo número para todos los números del 1 al 10.
#     10. Pedir al usuario que ingrese un número entero y luego imprimir una matriz triangular superior de ese tamaño con números aleatorios del 1 al 10.
